# %% [markdown]
# # Week 3: Building Real-World Housing Price Predictor
#
# **ML2: Advanced Machine Learning**
#
# ---
#
# This notebook contains teaching material, examples, and 10 practice questions to reinforce your understanding of this week's topics.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this week, you should be able to:
#
# - Loading and exploring the California Housing dataset
# - Feature normalization and standardization
# - Building a neural network regressor in PyTorch
# - Evaluating regression models: MSE, RMSE, R²

# %% [markdown]
# ## Setup
#
# Run this cell to import necessary libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim

# Set random seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)

print('✓ Libraries imported successfully')

# %% [markdown]
# ---
# ## Teaching Material
#
# ### Key Topics for Week 3
#
# 1. **Data preprocessing**
# 2. **Feature engineering**
# 3. **Model training**
# 4. **Evaluation metrics**

# %% [markdown]
# ### Example: Core Concept Demonstration
#
# Below is a simple example demonstrating one of this week's key concepts:

# %%
# Example code demonstrating a key concept
# TODO: Add specific examples for each lecture

print('Example for Week 3: Building Real-World Housing Price Predictor')

# %% [markdown]
# ---
# ## Practice Questions
#
# Complete the following 10 questions to test your understanding. Questions progress from conceptual to applied.
#
# **Instructions:**
# - Read each question carefully
# - Fill in code cells where indicated
# - Check your understanding with the provided hints
# - Solutions are available in a separate file

# %% [markdown]
# ### Question 1
#
# **Topic:** Data preprocessing
#
# [Question text for Question 1 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %%
# Your code here

# %% [markdown]
# ### Question 2
#
# **Topic:** Feature engineering
#
# [Question text for Question 2 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %%
# Your code here

# %% [markdown]
# ### Question 3
#
# **Topic:** Model training
#
# [Question text for Question 3 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %% [markdown]
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 4
#
# **Topic:** Evaluation metrics
#
# [Question text for Question 4 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %%
# Your code here

# %% [markdown]
# ### Question 5
#
# **Topic:** Data preprocessing
#
# [Question text for Question 5 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %%
# Your code here

# %% [markdown]
# ### Question 6
#
# **Topic:** Feature engineering
#
# [Question text for Question 6 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %% [markdown]
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 7
#
# **Topic:** Model training
#
# [Question text for Question 7 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %%
# Your code here

# %% [markdown]
# ### Question 8
#
# **Topic:** Evaluation metrics
#
# [Question text for Question 8 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %%
# Your code here

# %% [markdown]
# ### Question 9
#
# **Topic:** Data preprocessing
#
# [Question text for Question 9 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %% [markdown]
# **Your Answer:**
#
# [Write your answer here]

# %% [markdown]
# ### Question 10
#
# **Topic:** Feature engineering
#
# [Question text for Question 10 - to be customized per lecture]
#
# **Hint:** Think about how this concept relates to the learning objectives above.

# %%
# Your code here

# %% [markdown]
# ---
# ## Reflection
#
# Take a moment to reflect on what you've learned:
#
# 1. What was the most challenging concept this week?
# 2. How might you apply these concepts to a real-world problem?
# 3. What questions do you still have?
#
# **Your reflections:**

# %% [markdown]
# [Write your reflections here]

# %% [markdown]
# ---
# ## Additional Resources
#
# - Course textbook: See week's reading assignments
# - Office hours: Check course schedule
# - Course website: [Week 3 Materials](../../ml2/lecture03/index.html)
#
# **Next Steps:**
# - Review any questions you found challenging
# - Complete the week's coding assignments
# - Prepare for next week's topics
